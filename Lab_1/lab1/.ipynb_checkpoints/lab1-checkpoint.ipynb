# %% [markdown]
# <!-- -*- mode: markdown; coding: utf-8; fill-column: 60; ispell-dictionary: "english" -*- -->
#
# <meta charset="utf-8"/>
# <meta name="viewport" content="width=device-width,initial-scale=1"/>
# <link rel="stylesheet" href="style.css">
#
#
# # EDAF75 - lab 1: SQL
#
# **Objective:** to practice writing SQL queries.
#
# This lab is meant to be run as a `jupyter` notebook, you can
# download it [here](lab1.zip) (the zip-file contains the
# notebook and the database, and a [.html-file](lab1.html)
# which you can read in case you have problems reading/running
# jupyter notebooks).
#
# ## Background
#
# We have a database to handles the academic achievements of
# students at LTH -- in it we have three tables:
#
# <hr>
# <table rules="all">
#  <tr>
#   <th align="left"><code>students:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>ssn</code></td>
#   <td>social security number</td>
#  </tr>
#  <tr>
#   <td><code>first_name</code></td>
#   <td>first name (obviously!)</td>
#  </tr>
#  <tr>
#   <td><code>last_name</code></td>
#   <td>last name</td>
#  </tr>
# </table>
#
# <hr>
#
# <table rules="all">
#  <tr>
#   <th align="left"><code>courses:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>course_code</code></td>
#   <td>course code, like <code>EDAF75</code></td>
#  </tr>
#  <tr>
#   <td><code>course_name</code></td>
#   <td>the name of the course, like "Database Technology"</td>
#  </tr>
#  <tr>
#   <td><code>level</code></td>
#   <td>the course level, like "G1", "G2", or "A"</td>
#  </tr>
#  <tr>
#   <td><code>credits</code></td>
#   <td>the number of credits for the course, like 7.5</td>
#  </tr>
# </table>
#
# <hr>
#
# <table rules="all">
#  <tr>
#   <th align="left"><code>taken_courses:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>ssn</code></td>
#   <td>the social security number of a student</td>
#  </tr>
#  <tr>
#   <td><code>course_code</code></td>
#   <td>the course code for the course the student has taken</td>
#  </tr>
#  <tr>
#   <td><code>grade</code></td>
#   <td>the grade for the student passing the course</td>
#  </tr>
# </table>
#
# <hr>
#
# <center>
#   <img src="lab1.png">
# </center>
#
# Some sample data:

# %% [markdown]
# ```text
# ssn           first_name   last_name
# ---           ----------   ---------
# 861103–2438   Bo           Ek
# 911212–1746   Eva          Alm
# 950829–1848   Anna         Nyström
# ...           ...          ...
#
# course_code   course_name                   level    credits
# -----------   -----------                   -----    -------
# EDA016        Programmeringsteknik          G1       7.5
# EDAA01        Programmeringsteknik - FK     G1       7.5
# EDA230        Optimerande kompilatorer      A        7.5
# ...           ...                           ...      ...
#
# ssn           course_code   grade
# ---           -----------   -----
# 861103–2438   EDA016        4
# 861103–2438   EDAA01        3
# 911212–1746   EDA016        3
# ...           ...           ...
# ```

# %% [markdown]
# The tables have been created with the following SQL
# statements:

# %% [markdown]
# ```sql
# CREATE TABLE students (
#   ssn          CHAR(11),
#   first_name   TEXT NOT NULL,
#   last_name    TEXT NOT NULL,
#   PRIMARY KEY  (ssn)
# );
#
# CREATE TABLE courses (
#   course_code   CHAR(6),
#   course_name   TEXT NOT NULL,
#   level         CHAR(2),
#   credits       DOUBLE NOT NULL CHECK (credits > 0),
#   PRIMARY KEY   (course_code)
# );
#
# CREATE TABLE taken_courses (
#   ssn           CHAR(11),
#   course_code   CHAR(6),
#   grade         INTEGER NOT NULL CHECK (grade >= 3 AND grade <= 5),
#   PRIMARY KEY   (ssn, course_code),
#   FOREIGN KEY   (ssn) REFERENCES students(ssn),
#   FOREIGN KEY   (course_code) REFERENCES courses(course_code)
# );
# ```

# %% [markdown]
# All courses offered at the "Computer Science and
# Engineering" program at LTH during the academic year 2013/14
# are in the table 'courses`. Also, the database has been
# filled with made up data. SQL statements like the following
# have been used to insert the data:

# %% [markdown]
# ```sql
# INTO   students(ssn, first_name, last_name)
# VALUES ('950705-2308', 'Anna', 'Johansson'),
#        ('930702-3582', 'Anna', 'Johansson'),
#        ('911212-1746', 'Eva', 'Alm'),
#        ('910707-3787', 'Eva', 'Nilsson'),
#        ...
# ```

# %% [markdown]
# ## Assignments
#
# As said above, this lab is designed to be run as a jupyter
# notebook. If you haven't got jupyter running, you can run
# the sql-commands for the problems below interactively inside
# sqlite3, or as a script file with all your commands, or
# inside some IDE, like [DB Browser for
# SQLite](https://sqlitebrowser.org/).
#
# If you're running the lab as a notebook (and hopefully you
# are!), evaluate the following cells before you begin:

# %%
# %load_ext sql

# %%
# %sql sqlite:///lab1.sqlite
# Out:
# 'Connected: @lab1.sqlite'

# %% [markdown]
# The tables `students`, `courses` and `taken_courses` are
# already in your database, you can see some of their contents
# by running the cells below:

# %%
# %%sql
# SELECT  *
# FROM    students
# LIMIT   4
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('950705-2308', 'Anna', 'Johansson'),
#  ('930702-3582', 'Anna', 'Johansson'),
#  ('911212-1746', 'Eva', 'Alm'),
#  ('910707-3787', 'Eva', 'Nilsson')]

# %%
# %%sql
# SELECT  *
# FROM    courses
# LIMIT   4
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('EDA016', 'Programmeringsteknik', 'G1', 7.5),
#  ('EDA031', 'C++ - programmering', 'G2', 7.5),
#  ('EDA040', 'Realtidsprogrammering', 'G2', 6.0),
#  ('EDA050', 'Operativsystem', 'G2', 4.5)]

# %%
# %%sql
# SELECT  *
# FROM    taken_courses
# LIMIT   4
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('950705-2308', 'EITN35', 5),
#  ('950705-2308', 'ESS050', 3),
#  ('950705-2308', 'ETIN70', 4),
#  ('950705-2308', 'FMA140', 4)]

# %% [markdown]
# If you inadvertently change the contents of the tables, you
# can always recreate the them with the following command (it
# must be run at the command line):

# %% [markdown]
# ```sh
# sqlite3 lab1.sqlite < create-lab1-data.sql
# ```

# %% [markdown]
# After some of the questions there is a number in brackets.
# This is the number of rows generated by the question. For
# instance, [72] after question a) means that there are 72
# students in the database, you can use that number as an
# indicatation of if your answer is in the right ballpark.
#
# a) What are the names (first name, last name) of all the
#    students? [72]

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Anna', 'Johansson'),
#  ('Anna', 'Johansson'),
#  ('Eva', 'Alm'),
#  ('Eva', 'Nilsson'),
#  ('Elaine', 'Robertson'),
#  ('Maria', 'Nordman'),
#  ('Helena', 'Troberg'),
#  ('Lotta', 'Emanuelsson'),
#  ('Anna', 'Nyström'),
#  ('Maria', 'Andersson'),
#  ('Marie', 'Persson'),
#  ('Märit', 'Aspegren'),
#  ('Ylva', 'Jacobsson'),
#  ('Frida', 'Weidel'),
#  ('Caroline', 'Olsson'),
#  ('Karolin', 'Ek'),
#  ('Eva', 'Hjort'),
#  ('Sofia', 'Kjellberg'),
#  ('Tina', 'Lööf'),
#  ('Lisa', 'Berg'),
#  ('Lotta', 'Bergman'),
#  ('Susanne', 'Dahl'),
#  ('Birgit', 'Ewesson'),
#  ('Ulrika', 'Jonsson'),
#  ('Jenny', 'Lundin'),
#  ('Karin', 'Östberg'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Erik', 'Andersson'),
#  ('Erik', 'Andersson'),
#  ('Filip', 'Gustavsson'),
#  ('Niklas', 'Andersson'),
#  ('David', 'Carlsson'),
#  ('Tobias', 'Enberg'),
#  ('Johan', 'Lind'),
#  ('Magnus', 'Pettersson'),
#  ('Filip', 'Persson'),
#  ('Ola', 'Nilsson'),
#  ('Jakob', 'Malmberg'),
#  ('Henrik', 'Berg'),
#  ('John', 'Lind'),
#  ('Patrik', 'Lundh'),
#  ('Mikael', 'Nilsson'),
#  ('Joakim', 'Nilsson'),
#  ('Conny', 'Modig'),
#  ('Christian', 'Wallman'),
#  ('Magnus', 'Strömgren'),
#  ('Daniel', 'Ahlman'),
#  ('Lars', 'Molin'),
#  ('Magnus', 'Nilsson'),
#  ('Anders', 'Olsson'),
#  ('Martin', 'Alm'),
#  ('Håkan', 'Mossgren'),
#  ('Fredrik', 'Ryd'),
#  ('Mats', 'Wikström'),
#  ('Anders', 'Magnusson'),
#  ('Andreas', 'Molin'),
#  ('Johan', 'Brattberg'),
#  ('Johan', 'Olsson'),
#  ('Jonathan', 'Jönsson'),
#  ('Magnus', 'Hultgren'),
#  ('Axel', 'Nord'),
#  ('Henrik', 'Hult'),
#  ('Joakim', 'Hall'),
#  ('Henrik', 'Gustavsson'),
#  ('Torbjörn', 'Modig'),
#  ('Daniel', 'Axelsson'),
#  ('Per-Erik', 'Pettersson'),
#  ('Roger', 'Brorsson'),
#  ('Patrik', 'Ohlsson'),
#  ('Peter', 'Solberg')]

# %% [markdown]
# b) Same as question a) but produce a sorted listing. Sort
#    first by last name and then by first name.

# %%
# %%sql
# SELECT first_name, last_name
# FROM students
# ORDER BY last_name, first_name
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Daniel', 'Ahlman'),
#  ('Eva', 'Alm'),
#  ('Martin', 'Alm'),
#  ('Erik', 'Andersson'),
#  ('Erik', 'Andersson'),
#  ('Maria', 'Andersson'),
#  ('Niklas', 'Andersson'),
#  ('Märit', 'Aspegren'),
#  ('Daniel', 'Axelsson'),
#  ('Henrik', 'Berg'),
#  ('Lisa', 'Berg'),
#  ('Lotta', 'Bergman'),
#  ('Johan', 'Brattberg'),
#  ('Roger', 'Brorsson'),
#  ('David', 'Carlsson'),
#  ('Susanne', 'Dahl'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Karolin', 'Ek'),
#  ('Lotta', 'Emanuelsson'),
#  ('Tobias', 'Enberg'),
#  ('Birgit', 'Ewesson'),
#  ('Filip', 'Gustavsson'),
#  ('Henrik', 'Gustavsson'),
#  ('Joakim', 'Hall'),
#  ('Eva', 'Hjort'),
#  ('Henrik', 'Hult'),
#  ('Magnus', 'Hultgren'),
#  ('Ylva', 'Jacobsson'),
#  ('Anna', 'Johansson'),
#  ('Anna', 'Johansson'),
#  ('Ulrika', 'Jonsson'),
#  ('Jonathan', 'Jönsson'),
#  ('Sofia', 'Kjellberg'),
#  ('Johan', 'Lind'),
#  ('John', 'Lind'),
#  ('Patrik', 'Lundh'),
#  ('Jenny', 'Lundin'),
#  ('Tina', 'Lööf'),
#  ('Anders', 'Magnusson'),
#  ('Jakob', 'Malmberg'),
#  ('Conny', 'Modig'),
#  ('Torbjörn', 'Modig'),
#  ('Andreas', 'Molin'),
#  ('Lars', 'Molin'),
#  ('Håkan', 'Mossgren'),
#  ('Eva', 'Nilsson'),
#  ('Joakim', 'Nilsson'),
#  ('Magnus', 'Nilsson'),
#  ('Mikael', 'Nilsson'),
#  ('Ola', 'Nilsson'),
#  ('Axel', 'Nord'),
#  ('Maria', 'Nordman'),
#  ('Anna', 'Nyström'),
#  ('Patrik', 'Ohlsson'),
#  ('Anders', 'Olsson'),
#  ('Caroline', 'Olsson'),
#  ('Johan', 'Olsson'),
#  ('Filip', 'Persson'),
#  ('Marie', 'Persson'),
#  ('Magnus', 'Pettersson'),
#  ('Per-Erik', 'Pettersson'),
#  ('Elaine', 'Robertson'),
#  ('Fredrik', 'Ryd'),
#  ('Peter', 'Solberg'),
#  ('Magnus', 'Strömgren'),
#  ('Helena', 'Troberg'),
#  ('Christian', 'Wallman'),
#  ('Frida', 'Weidel'),
#  ('Mats', 'Wikström'),
#  ('Karin', 'Östberg')]

# %% [markdown]
# c) What are the names of the students who were born in 1985?
#    [4]

# %%
# %%sql
# SELECT first_name, last_name, substr(ssn,1,2) as year_born
# FROM students
# WHERE year_born = '85'
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Ulrika', 'Jonsson', '85'),
#  ('Bo', 'Ek', '85'),
#  ('Filip', 'Persson', '85'),
#  ('Henrik', 'Berg', '85')]

# %% [markdown]
# d) The next-to-last digit in the social security number is
#    even for females, and odd for males. List the first names
#    of all female students in our database alphabetically
#    (each name should occur only once). Hint: the `substr`
#    function can be useful. [26]

# %%
# %%sql
# SELECT DISTINCT first_name, substr(ssn,10,1) AS gender_number
# FROM students
# WHERE CAST(gender_number AS int) % 2 = 0
# ORDER BY first_name
# --The distinct function is probably not working as intended here, how do I select distinct on simply first name?
# --Is it necessary to create a new table?
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Anna', '0'),
#  ('Anna', '8'),
#  ('Anna', '4'),
#  ('Birgit', '6'),
#  ('Caroline', '6'),
#  ('Elaine', '2'),
#  ('Eva', '4'),
#  ('Eva', '8'),
#  ('Eva', '6'),
#  ('Frida', '4'),
#  ('Helena', '2'),
#  ('Jenny', '2'),
#  ('Karin', '0'),
#  ('Karolin', '6'),
#  ('Lisa', '2'),
#  ('Lotta', '2'),
#  ('Lotta', '8'),
#  ('Maria', '4'),
#  ('Maria', '6'),
#  ('Marie', '4'),
#  ('Märit', '6'),
#  ('Sofia', '4'),
#  ('Susanne', '6'),
#  ('Tina', '4'),
#  ('Ulrika', '6'),
#  ('Ylva', '0')]

# %% [markdown]
# e) How many students are registered in the database?

# %%
# %%sql
# SELECT count(1)
# FROM students
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(72,)]

# %% [markdown]
# f) Which courses are offered by the department of
#    Mathematics (their course codes have the form `FMAxxx`)?
#    [22]

# %%
# %%sql
# SELECT COUNT substr(course_code,1,3) AS department_number, course_name
# FROM courses
# WHERE department_number = 'FMA'
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('FMA', 'Kontinuerliga system'),
#  ('FMA', 'Optimering'),
#  ('FMA', 'Diskret matematik'),
#  ('FMA', 'Matematiska strukturer'),
#  ('FMA', 'Matristeori'),
#  ('FMA', 'Matristeori, projektdel'),
#  ('FMA', 'Geometri'),
#  ('FMA', 'Olinjära dynamiska system'),
#  ('FMA', 'Olinjära dynamiska system, projektdel'),
#  ('FMA', 'Bildanalys'),
#  ('FMA', 'Bildanalys, projektdel'),
#  ('FMA', 'Variationskalkyl'),
#  ('FMA', 'Linjär och kombinatorisk optimering'),
#  ('FMA', 'Datorseende'),
#  ('FMA', 'Datorseende, projektdel'),
#  ('FMA', 'Linjär algebra'),
#  ('FMA', 'Flerdimensionell analys'),
#  ('FMA', 'Endimensionell analys'),
#  ('FMA', 'Matematik - Funktionsteori'),
#  ('FMA', 'Matematik - System och transformer'),
#  ('FMA', 'Tillämpad matematik - Linjära system'),
#  ('FMA', 'Algebraiska strukturer')]

# %% [markdown]
# g) Which courses give more than 7.5 credits? [16]

# %%
# %%sql
# SELECT course_name, course_code, credits
# FROM courses
# WHERE credits > 7.5
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Coachning av programvaruteam', 'EDA270', 9.0),
#  ('Datorer i system', 'EDAA05', 8.0),
#  ('Tillämpad mekatronik', 'EIEF01', 10.0),
#  ('Mekatronik, industriell produktframtagning', 'EIEN01', 10.0),
#  ('Digitalteknik', 'EIT020', 9.0),
#  ('Digitala bilder – kompression', 'EITF01', 9.0),
#  ('Elektromagnetisk fältteori', 'ESS050', 9.0),
#  ('Elektronik', 'ETIA01', 8.0),
#  ('Introduktionskurs i kinesiska för civilingenjörer', 'EXTA35', 15.0),
#  ('Introduktionskurs i kinesiska för civilingenjörer, del 2', 'EXTF60', 15.0),
#  ('Fysik', 'FAFF25', 11.0),
#  ('Endimensionell analys', 'FMAA01', 15.0),
#  ('Matematisk statistik, allmän kurs', 'FMS012', 9.0),
#  ('Realtidssystem', 'FRTN01', 10.0),
#  ('Japanska för tekniker', 'GEMA70', 15.0),
#  ('Industriell ekonomi, allmän kurs', 'MIOA01', 9.0)]

# %% [markdown]
# h) How may courses are there for each level (`G1`, `G2`, and
#    `A`)?

# %%
# %%sql
#
#
# SELECT COUNT(level)
# FROM courses
# WHERE level = 'G1'
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(31,)]

# %% [markdown]
# In the next few problems, we'll look at the results of the
# student with the social security number 910101–1234 -- to
# make things a lot easier, you can create a `VIEW` with all
# his results (see lecture 3).

# %%
# %%sql
# DROP VIEW IF EXISTS student_info;
# CREATE VIEW student_info AS
# SELECT ssn, first_name, last_name, course_code, grade, credits, course_name
# FROM students
# JOIN taken_courses
# USING (ssn)
# JOIN courses
# USING (course_code)
# WHERE ssn = '910101-1234'
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# Done.
# []

# %%
# %%sql
# SELECT course_code
# FROM student_info
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('EDA070',),
#  ('EDA385',),
#  ('EDAA25',),
#  ('EDAF05',),
#  ('EEMN10',),
#  ('EIT020',),
#  ('EIT060',),
#  ('EITF40',),
#  ('EITN40',),
#  ('EITN50',),
#  ('ESS050',),
#  ('ETIF10',),
#  ('ETIF15',),
#  ('ETIN35',),
#  ('ETS052',),
#  ('ETS075',),
#  ('ETS200',),
#  ('ETSA01',),
#  ('EXTA10',),
#  ('EXTA35',),
#  ('FAFF20',),
#  ('FAFF25',),
#  ('FMA145',),
#  ('FMA420',),
#  ('FMAA01',),
#  ('FMAF05',),
#  ('FMS012',),
#  ('FMSF15',),
#  ('FMSN30',),
#  ('FMSN35',),
#  ('FRTN10',),
#  ('GEMA45',),
#  ('GEMA70',),
#  ('MAMF15',),
#  ('TEK210',)]

# %% [markdown]
# i) Which courses (course codes only) have been taken by the
#    student with the social security number 910101–1234? [35]

# %%
# %%sql
# SELECT course_name, credits
# FROM student_info
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Datorer och datoranvändning', 3.0),
#  ('Konstruktion av inbyggda system, fördjupningskurs', 7.5),
#  ('C-programmering', 3.0),
#  ('Algoritmer, datastrukturer och komplexitet', 5.0),
#  ('Datorbaserade mätsystem', 7.5),
#  ('Digitalteknik', 9.0),
#  ('Datasäkerhet', 7.5),
#  ('Digitala och analoga projekt', 7.5),
#  ('Avancerad webbsäkerhet', 4.0),
#  ('Avancerad datasäkerhet', 7.5),
#  ('Elektromagnetisk fältteori', 9.0),
#  ('Signalbehandling - design och implementering', 7.5),
#  ('Medicinsk signalbehandling', 7.5),
#  ('IC-projekt 1', 7.5),
#  ('Datorkommunikation', 4.5),
#  ('Kösystem', 4.5),
#  ('Programvarutestning', 7.5),
#  ('Ingenjörsprocessen för programvaruutveckling - metodik', 5.0),
#  ('Introduktion till Kinas samhällsliv, kultur och språk', 3.0),
#  ('Introduktionskurs i kinesiska för civilingenjörer', 15.0),
#  ('Multispektral avbildning', 7.5),
#  ('Fysik', 11.0),
#  ('Olinjära dynamiska system, projektdel', 3.0),
#  ('Linjär algebra', 6.0),
#  ('Endimensionell analys', 15.0),
#  ('Matematik - System och transformer', 7.0),
#  ('Matematisk statistik, allmän kurs', 9.0),
#  ('Markovprocesser', 7.5),
#  ('Linjär och logistisk regression', 7.5),
#  ('Stationär och icke-stationär spektralanalys', 7.5),
#  ('Flervariabel reglering', 7.5),
#  ('Förståelse och lärande', 3.0),
#  ('Japanska för tekniker', 15.0),
#  ('Arbetsorganisation och ledarskap', 6.0),
#  ('Kognition', 4.5)]

# %% [markdown]
# j) What are the names of these courses, and how many credits
#    do they give?

# %%
# %%sql
# SELECT SUM(credits)
# FROM student_info
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(249.5,)]

# %% [markdown]
# k) How many credits has the student taken?

# %%
# %%sql
# SELECT AVG(grade)
# FROM student_info
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(4.0285714285714285,)]

# %% [markdown]
# l) Which is the student’s grade average?

# %%
# %%sql
# SELECT *
# FROM students
# LEFT OUTER JOIN taken_courses ON students.ssn = taken_courses.ssn
# ORDER BY course_code
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('950829-1848', 'Anna', 'Nyström', None, None, None),
#  ('870909-3367', 'Caroline', 'Olsson', None, None, None),
#  ('931225-3158', 'Bo', 'Ek', None, None, None),
#  ('891220-1393', 'Erik', 'Andersson', None, None, None),
#  ('900313-2257', 'Erik', 'Andersson', None, None, None),
#  ('891007-3091', 'Johan', 'Lind', None, None, None),
#  ('850517-2597', 'Filip', 'Persson', None, None, None),
#  ('911015-3758', 'Jonathan', 'Jönsson', None, None, None),
#  ('950125-1153', 'Magnus', 'Hultgren', None, None, None),
#  ('880206-1915', 'Joakim', 'Hall', None, None, None),
#  ('900129-3374', 'Henrik', 'Gustavsson', None, None, None),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDA016', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA016', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDA016', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDA016', 3),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EDA016', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EDA016', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EDA016', 5),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EDA016', 3),
#  ('950715-2090', 'Axel', 'Nord', '950715-2090', 'EDA016', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDA016', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EDA031', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA031', 4),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EDA031', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDA031', 5),
#  ('900526-1450', 'Magnus', 'Nilsson', '900526-1450', 'EDA031', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDA031', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDA040', 4),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'EDA040', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA040', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EDA040', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EDA040', 3),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'EDA040', 4),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EDA050', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDA050', 3),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EDA050', 5),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'EDA050', 3),
#  ('860323-1071', 'Niklas', 'Andersson', '860323-1071', 'EDA050', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA050', 3),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EDA050', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDA050', 3),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EDA070', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDA070', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDA070', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EDA070', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EDA070', 3),
#  ('941003-1225', 'Lotta', 'Emanuelsson', '941003-1225', 'EDA095', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDA095', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA095', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDA095', 5),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EDA095', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EDA095', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EDA095', 5),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'EDA095', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EDA132', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDA132', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA132', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDA132', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDA132', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDA180', 4),
#  ('941003-1225', 'Lotta', 'Emanuelsson', '941003-1225', 'EDA180', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDA180', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDA180', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDA180', 5),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'EDA180', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA180', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EDA180', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDA180', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA221', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EDA221', 4),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'EDA221', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDA221', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDA221', 3),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'EDA221', 5),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EDA221', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDA221', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDA221', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDA230', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA230', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDA230', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDA230', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDA230', 4),
#  ('931015-1271', 'Magnus', 'Strömgren', '931015-1271', 'EDA230', 4),
#  ('950714-2190', 'Håkan', 'Mossgren', '950714-2190', 'EDA230', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDA260', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDA260', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDA260', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDA260', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA260', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDA260', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'EDA260', 3),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EDA260', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDA260', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EDA270', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EDA270', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'EDA270', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDA270', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDA385', 3),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'EDA385', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDA385', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDA385', 4),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'EDA385', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDA385', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EDA385', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDAA01', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAA01', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EDAA01', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAA01', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDAA01', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAA05', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EDAA05', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDAA05', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EDAA05', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAA05', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDAA25', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAA25', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDAA25', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EDAA25', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDAA25', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EDAA25', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EDAF01', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAF01', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDAF01', 3),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'EDAF01', 5),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EDAF01', 5),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EDAF01', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EDAF01', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EDAF01', 3),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EDAF05', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAF05', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDAF05', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EDAF05', 3),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'EDAF05', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDAF05', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EDAF05', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDAF10', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDAF10', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAF10', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EDAF10', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'EDAF10', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDAF10', 4),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EDAF10', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAF10', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDAF10', 4),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EDAF10', 4),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EDAF10', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'EDAF15', 5),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EDAF15', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDAF15', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDAF15', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EDAF15', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDAF15', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDAF75', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EDAF75', 4),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDAF75', 4),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EDAF75', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDAN01', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAN01', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'EDAN01', 3),
#  ('920812-1857', 'Jakob', 'Malmberg', '920812-1857', 'EDAN01', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EDAN01', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EDAN01', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDAN01', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAN01', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EDAN01', 5),
#  ('941003-1225', 'Lotta', 'Emanuelsson', '941003-1225', 'EDAN10', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EDAN10', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDAN10', 3),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'EDAN10', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EDAN10', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EDAN10', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EDAN10', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EDAN10', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EDAN10', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDAN15', 5),
#  ('910707-3787', 'Eva', 'Nilsson', '910707-3787', 'EDAN15', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAN15', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAN15', 4),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDAN15', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAN15', 4),
#  ('930716-3933', 'Patrik', 'Lundh', '930716-3933', 'EDAN15', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EDAN15', 3),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'EDAN15', 3),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EDAN20', 3),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'EDAN20', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAN20', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDAN20', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDAN20', 3),
#  ('860323-1071', 'Niklas', 'Andersson', '860323-1071', 'EDAN20', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDAN20', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDAN20', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EDAN25', 3),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'EDAN25', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EDAN25', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAN25', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDAN30', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAN30', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDAN30', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'EDAN30', 3),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EDAN30', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EDAN30', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EDAN30', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAN35', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDAN35', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDAN35', 5),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDAN35', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDAN35', 5),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EDAN35', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAN35', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EDAN35', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDAN40', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAN40', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAN40', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDAN40', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDAN40', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDAN40', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDAN50', 5),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'EDAN50', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDAN55', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'EDAN55', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDAN55', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'EDAN55', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EDAN55', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EDAN55', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAN55', 5),
#  ('930716-3933', 'Patrik', 'Lundh', '930716-3933', 'EDAN55', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EDAN55', 3),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EDAN55', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EDAN55', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDAN55', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EDAN55', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EDAN55', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EDAN60', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDAN60', 3),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EDAN60', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'EDAN60', 5),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'EDAN60', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDAN60', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EDAN60', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EDAN60', 4),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'EDI042', 3),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EDI042', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EDI042', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDI042', 4),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EDI042', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EDI042', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EDIN01', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EDIN01', 3),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EDIN01', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EDIN01', 4),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'EDIN01', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EDIN01', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EDIN05', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EDIN05', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EDIN05', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EDIN05', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EDIN05', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EDIN05', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EDIN05', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EDIN05', 4),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'EDIN05', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EDIN05', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'EEM031', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EEM031', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EEM031', 5),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'EEM031', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EEMF05', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EEMF05', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EEMF05', 4),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'EEMF05', 3),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'EEMF05', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EEMF05', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EEMN01', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EEMN01', 3),
#  ('920812-1857', 'Jakob', 'Malmberg', '920812-1857', 'EEMN01', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EEMN01', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EEMN01', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EEMN05', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EEMN05', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EEMN10', 4),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EEMN10', 5),
#  ('950317-3520', 'Lisa', 'Berg', '950317-3520', 'EEMN10', 4),
#  ('850706-2762', 'Ulrika', 'Jonsson', '850706-2762', 'EEMN10', 4),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EEMN10', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EEMN10', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EEMN10', 3),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EEMN10', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EEMN10', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EEMN10', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EEMN10', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EEMN10', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EEMN15', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EEMN15', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EEMN15', 3),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EEMN15', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EEMN15', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EEMN15', 4),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'EIE061', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EIE061', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EIE061', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EIE061', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EIE061', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EIE061', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EIE061', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EIE061', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EIEF01', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EIEF01', 5),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EIEF01', 4),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EIEF01', 4),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'EIEF01', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EIEF01', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EIEF01', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EIEF01', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EIEF01', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EIEF01', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EIEN01', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EIEN01', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EIEN01', 5),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EIEN01', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EIEN01', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EIEN01', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EIEN01', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EIEN01', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EIT020', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EIT020', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EIT020', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EIT020', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EIT020', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EIT020', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EIT020', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EIT060', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EIT060', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EIT060', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EIT060', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EIT060', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EIT060', 4),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'EIT070', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EIT070', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EIT070', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EIT070', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EIT070', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EIT070', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EIT070', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EIT070', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EIT070', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EIT140', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EIT140', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EIT140', 4),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'EIT140', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EIT140', 4),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EIT140', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EIT140', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EIT140', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EIT140', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'EIT140', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EITF01', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EITF01', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EITF01', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EITF01', 4),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EITF01', 4),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EITF01', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EITF01', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EITF01', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EITF01', 3),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'EITF01', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'EITF05', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EITF05', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EITF05', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EITF05', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EITF05', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'EITF05', 4),
#  ('930420-2833', 'John', 'Lind', '930420-2833', 'EITF05', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EITF05', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EITF05', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EITF05', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EITF20', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'EITF20', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EITF20', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EITF20', 5),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'EITF20', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EITF20', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EITF20', 4),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'EITF35', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EITF35', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EITF35', 4),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EITF35', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EITF35', 5),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EITF35', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EITF40', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EITF40', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EITF40', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'EITF40', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'EITF40', 5),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EITF40', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EITF40', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EITF40', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'EITN10', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EITN10', 4),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'EITN10', 5),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'EITN10', 3),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EITN10', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EITN10', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EITN10', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EITN10', 4),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'EITN30', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EITN30', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EITN30', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EITN30', 4),
#  ('950705-2308', 'Anna', 'Johansson', '950705-2308', 'EITN35', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'EITN35', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EITN35', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EITN35', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'EITN35', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EITN35', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EITN35', 5),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EITN40', 5),
#  ('920812-1857', 'Jakob', 'Malmberg', '920812-1857', 'EITN40', 5),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'EITN40', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EITN40', 4),
#  ('920514-3433', 'Johan', 'Olsson', '920514-3433', 'EITN40', 5),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'EITN40', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EITN40', 3),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EITN45', 3),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EITN45', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EITN45', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'EITN50', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EITN50', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'EITN50', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'EITN50', 5),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EITN50', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'EITN50', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EITN50', 4),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'ESS030', 4),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ESS030', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ESS030', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'ESS030', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ESS030', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ESS030', 5),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ESS030', 5),
#  ('920514-3433', 'Johan', 'Olsson', '920514-3433', 'ESS030', 4),
#  ('950705-2308', 'Anna', 'Johansson', '950705-2308', 'ESS050', 3),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'ESS050', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ESS050', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'ESS050', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ESS050', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ESS050', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'ESS050', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ESS050', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ESSF10', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'ESSF10', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ESSF10', 4),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'ESSF10', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ESSF10', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ESSF10', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ESSF10', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'ESSF10', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETI265', 5),
#  ('850706-2762', 'Ulrika', 'Jonsson', '850706-2762', 'ETI265', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'ETI265', 5),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'ETI265', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETI265', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETIA01', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'ETIA01', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETIA01', 3),
#  ('860323-1071', 'Niklas', 'Andersson', '860323-1071', 'ETIA01', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIA01', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETIA01', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETIA01', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'ETIA01', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETIA10', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIA10', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ETIA10', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'ETIF05', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETIF05', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'ETIF05', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETIF05', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'ETIF05', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETIF05', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETIF05', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ETIF05', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETIF10', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETIF10', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETIF10', 3),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETIF10', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETIF10', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETIF10', 5),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'ETIF10', 4),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'ETIF10', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETIF10', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETIF10', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETIF10', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ETIF10', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'ETIF10', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETIF10', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETIF15', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETIF15', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIF15', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETIF15', 3),
#  ('920812-1857', 'Jakob', 'Malmberg', '920812-1857', 'ETIF15', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'ETIF15', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETIF15', 5),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'ETIN10', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETIN10', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETIN10', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETIN10', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'ETIN10', 5),
#  ('930716-3933', 'Patrik', 'Lundh', '930716-3933', 'ETIN10', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETIN10', 4),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'ETIN15', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETIN15', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETIN15', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETIN15', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETIN15', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'ETIN15', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETIN15', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIN15', 5),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'ETIN15', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETIN15', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETIN20', 3),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETIN20', 4),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'ETIN20', 5),
#  ('931015-1271', 'Magnus', 'Strömgren', '931015-1271', 'ETIN20', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETIN20', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETIN20', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETIN35', 5),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'ETIN35', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETIN35', 4),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'ETIN35', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETIN35', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETIN35', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETIN40', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIN40', 3),
#  ('931015-1271', 'Magnus', 'Strömgren', '931015-1271', 'ETIN40', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETIN40', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'ETIN40', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'ETIN45', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETIN45', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETIN45', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIN45', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'ETIN45', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETIN45', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'ETIN55', 4),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETIN55', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETIN55', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETIN55', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETIN55', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETIN55', 4),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'ETIN55', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETIN55', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'ETIN55', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'ETIN55', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETIN60', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETIN60', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETIN60', 5),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'ETIN60', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'ETIN60', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETIN60', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETIN60', 5),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'ETIN60', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETIN60', 3),
#  ('950705-2308', 'Anna', 'Johansson', '950705-2308', 'ETIN70', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'ETIN70', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETIN80', 3),
#  ('860323-1071', 'Niklas', 'Andersson', '860323-1071', 'ETIN80', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETS052', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETS052', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETS052', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'ETS052', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETS052', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ETS052', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETS052', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'ETS052', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETS052', 5),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETS061', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETS061', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETS061', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'ETS061', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETS075', 4),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'ETS075', 3),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'ETS075', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETS075', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETS170', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETS170', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETS170', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETS170', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETS170', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'ETS170', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETS170', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ETS170', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETS170', 3),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'ETS170', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETS200', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'ETS200', 4),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETS200', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETS200', 4),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'ETS200', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETS200', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETS200', 5),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ETS200', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETS200', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETS200', 3),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'ETSA01', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETSA01', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETSA01', 3),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'ETSA01', 5),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ETSA01', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETSA01', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'ETSA01', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETSA05', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETSA05', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETSA05', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETSA05', 3),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'ETSA05', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETSA05', 4),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'ETSA05', 3),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'ETSA05', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'ETSA05', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'ETSA05', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'ETSA05', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETSA05', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETSF01', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'ETSF01', 4),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETSF01', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETSF01', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'ETSF01', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETSF01', 3),
#  ('950714-2190', 'Håkan', 'Mossgren', '950714-2190', 'ETSF01', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'ETSF01', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETSF01', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETSF10', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETSF10', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'ETSF10', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETSF10', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETSF10', 5),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'ETSF10', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETSF10', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETSF10', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'ETSF10', 3),
#  ('910707-3787', 'Eva', 'Nilsson', '910707-3787', 'ETSN01', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETSN01', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'ETSN01', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETSN01', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'ETSN01', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETSN01', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETSN01', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'ETSN01', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'ETSN01', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETSN05', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETSN05', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETSN05', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETSN05', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'ETSN05', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETSN05', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'ETSN05', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ETSN05', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETT051', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'ETT051', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'ETT051', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'ETT051', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'ETT051', 5),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'ETT051', 4),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'ETT051', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETT051', 5),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'ETT051', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'ETT051', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'ETTN01', 3),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'ETTN01', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETTN01', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'ETTN01', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETTN01', 4),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'ETTN05', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'ETTN05', 3),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'ETTN05', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETTN05', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'ETTN05', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'ETTN05', 3),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'ETTN10', 4),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'ETTN10', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'ETTN10', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'ETTN10', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'ETTN10', 3),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'ETTN10', 3),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETTN10', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'ETTN15', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'ETTN15', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'ETTN15', 5),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'ETTN15', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'ETTN15', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EXTA10', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'EXTA10', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EXTA10', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'EXTA10', 5),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'EXTA10', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'EXTA10', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EXTA10', 3),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'EXTA10', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EXTA10', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'EXTA10', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EXTA10', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'EXTA35', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'EXTA35', 4),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'EXTA35', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EXTA35', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'EXTA35', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'EXTA35', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'EXTA35', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'EXTF60', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'EXTF60', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'EXTF60', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'EXTF60', 4),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'EXTF60', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'EXTF60', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'EXTF60', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'EXTF60', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FAF150', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FAF150', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FAF150', 5),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FAF150', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FAF150', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FAF150', 3),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'FAF150', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FAFF20', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FAFF20', 4),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'FAFF20', 5),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'FAFF20', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FAFF20', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'FAFF25', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FAFF25', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FAFF25', 5),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FAFF25', 3),
# ...
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'FMA091', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'FMA091', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMA091', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA111', 5),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'FMA111', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA111', 5),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'FMA120', 5),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'FMA120', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMA120', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMA125', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'FMA125', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMA125', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'FMA125', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMA125', 4),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FMA125', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA125', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMA125', 3),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'FMA125', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA125', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'FMA125', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'FMA125', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMA135', 3),
#  ('900528-1540', 'Sofia', 'Kjellberg', '900528-1540', 'FMA135', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'FMA135', 5),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FMA135', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'FMA135', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA135', 5),
#  ('950705-2308', 'Anna', 'Johansson', '950705-2308', 'FMA140', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMA140', 4),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FMA140', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMA140', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMA140', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'FMA140', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMA140', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA140', 3),
#  ('910308-1826', 'Helena', 'Troberg', '910308-1826', 'FMA145', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMA145', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'FMA145', 5),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'FMA145', 3),
#  ('891231-2554', 'Lars', 'Molin', '891231-2554', 'FMA145', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMA145', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA145', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'FMA145', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FMA145', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'FMA170', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMA170', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMA170', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FMA170', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA170', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMA175', 4),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'FMA175', 3),
#  ('920812-1857', 'Jakob', 'Malmberg', '920812-1857', 'FMA175', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMA175', 4),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'FMA175', 3),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'FMA175', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'FMA200', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMA200', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMA200', 4),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FMA200', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA200', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA200', 4),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'FMA200', 5),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'FMA200', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'FMA240', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'FMA240', 4),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMA240', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA240', 4),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMA240', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'FMA240', 3),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMA240', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'FMA240', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMA270', 3),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'FMA270', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMA270', 3),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMA270', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMA270', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMA270', 4),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FMA272', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMA272', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'FMA272', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMA272', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'FMA272', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMA272', 4),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMA272', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMA272', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMA272', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMA420', 5),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'FMA420', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMA420', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMA420', 5),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FMA420', 5),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'FMA430', 4),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMA430', 3),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'FMA430', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'FMA430', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'FMA430', 5),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMA430', 4),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'FMA430', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMA430', 4),
#  ('890103-1256', 'Johan', 'Brattberg', '890103-1256', 'FMA430', 3),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMAA01', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FMAA01', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FMAA01', 4),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FMAA01', 3),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMAA01', 5),
#  ('930716-3933', 'Patrik', 'Lundh', '930716-3933', 'FMAA01', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FMAA01', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FMAF01', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMAF01', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMAF01', 3),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMAF01', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'FMAF05', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMAF05', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMAF05', 5),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMAF05', 3),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'FMAF05', 4),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FMAF05', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMAF10', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'FMAF10', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMAF10', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'FMAF10', 4),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMAF10', 4),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMAF10', 4),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMAN10', 5),
#  ('931213-2824', 'Elaine', 'Robertson', '931213-2824', 'FMAN10', 3),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'FMAN10', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'FMAN10', 3),
#  ('940825-1934', 'Filip', 'Gustavsson', '940825-1934', 'FMAN10', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMAN10', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMAN10', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMAN10', 4),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'FMAN10', 3),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'FMAN10', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMI040', 5),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'FMI040', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMI040', 3),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMI040', 5),
#  ('930502-2040', 'Tina', 'Lööf', '930502-2040', 'FMI040', 5),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FMI040', 5),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMI040', 5),
#  ('850208-1213', 'Henrik', 'Berg', '850208-1213', 'FMI040', 3),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMI040', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'FMI040', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMI050', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FMI050', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMI050', 3),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMI050', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'FMI050', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMI050', 5),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'FMI050', 4),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'FMIF15', 3),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'FMIF15', 4),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMIF15', 5),
#  ('890622-1928', 'Jenny', 'Lundin', '890622-1928', 'FMIF15', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FMIF15', 5),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMIF15', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMIF15', 5),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMIF15', 4),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'FMIF15', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMN011', 3),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'FMN011', 4),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'FMN011', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMN011', 3),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'FMN011', 3),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMN011', 5),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FMN100', 5),
#  ('860323-1071', 'Niklas', 'Andersson', '860323-1071', 'FMN100', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMN100', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMN100', 3),
#  ('891106-1277', 'Anders', 'Magnusson', '891106-1277', 'FMN100', 5),
#  ('910707-3787', 'Eva', 'Nilsson', '910707-3787', 'FMNN05', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'FMNN05', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'FMNN05', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMNN05', 3),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMNN05', 3),
#  ('861103-2438', 'Bo', 'Ek', '861103-2438', 'FMNN05', 5),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FMNN05', 5),
#  ('890621-3057', 'Ola', 'Nilsson', '890621-3057', 'FMNN05', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'FMNN05', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMNN05', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMNN05', 5),
#  ('901030-1895', 'Per-Erik', 'Pettersson', '901030-1895', 'FMNN05', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMNN05', 3),
#  ('950317-3520', 'Lisa', 'Berg', '950317-3520', 'FMNN25', 5),
#  ('891021-1287', 'Lotta', 'Bergman', '891021-1287', 'FMNN25', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMNN25', 4),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'FMNN25', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMNN25', 3),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'FMS012', 3),
#  ('870915-2742', 'Marie', 'Persson', '870915-2742', 'FMS012', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMS012', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMS012', 5),
#  ('900918-3999', 'Henrik', 'Hult', '900918-3999', 'FMS012', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'FMS012', 4),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMS012', 3),
#  ('910101-1234', 'Peter', 'Solberg', '910101-1234', 'FMS012', 3),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMS051', 5),
#  ('931128-1333', 'Joakim', 'Nilsson', '931128-1333', 'FMS051', 4),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'FMS051', 5),
#  ('920921-2499', 'Roger', 'Brorsson', '920921-2499', 'FMS051', 4),
#  ('951122-1048', 'Maria', 'Nordman', '951122-1048', 'FMS072', 3),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FMS072', 4),
#  ('880620-2564', 'Susanne', 'Dahl', '880620-2564', 'FMS072', 5),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'FMS072', 5),
#  ('900206-3735', 'Daniel', 'Ahlman', '900206-3735', 'FMS072', 4),
#  ('921222-2113', 'Mats', 'Wikström', '921222-2113', 'FMS072', 3),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMS091', 3),
#  ('860819-2864', 'Maria', 'Andersson', '860819-2864', 'FMS091', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMS091', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMS091', 5),
#  ('860206-1065', 'Eva', 'Hjort', '860206-1065', 'FMS091', 3),
#  ('850819-2139', 'Bo', 'Ek', '850819-2139', 'FMS091', 4),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMS091', 3),
#  ('890820-2496', 'Tobias', 'Enberg', '890820-2496', 'FMS091', 4),
#  ('920623-3258', 'Magnus', 'Pettersson', '920623-3258', 'FMS091', 4),
#  ('940318-2373', 'Conny', 'Modig', '940318-2373', 'FMS091', 4),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMS091', 3),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMS091', 3),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMS091', 4),
#  ('930804-3050', 'Patrik', 'Ohlsson', '930804-3050', 'FMS091', 3),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMS110', 5),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'FMS110', 5),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMS110', 3),
#  ('910226-3409', 'Karin', 'Östberg', '910226-3409', 'FMS110', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMS110', 5),
#  ('921029-1995', 'Daniel', 'Axelsson', '921029-1995', 'FMS110', 3),
#  ('911212-1746', 'Eva', 'Alm', '911212-1746', 'FMS155', 4),
#  ('931208-3605', 'Ylva', 'Jacobsson', '931208-3605', 'FMS155', 5),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMS155', 3),
#  ('920308-3854', 'David', 'Carlsson', '920308-3854', 'FMS155', 5),
#  ('940801-2971', 'Mikael', 'Nilsson', '940801-2971', 'FMS155', 5),
#  ('911020-3538', 'Fredrik', 'Ryd', '911020-3538', 'FMS155', 4),
#  ('920906-3371', 'Andreas', 'Molin', '920906-3371', 'FMS155', 5),
#  ('930702-3582', 'Anna', 'Johansson', '930702-3582', 'FMSF10', 5),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMSF10', 3),
#  ('910915-2068', 'Karolin', 'Ek', '910915-2068', 'FMSF10', 4),
#  ('940802-3861', 'Birgit', 'Ewesson', '940802-3861', 'FMSF10', 4),
#  ('881030-2772', 'Christian', 'Wallman', '881030-2772', 'FMSF10', 3),
#  ('950830-2637', 'Anders', 'Olsson', '950830-2637', 'FMSF10', 5),
#  ('880322-3951', 'Martin', 'Alm', '880322-3951', 'FMSF10', 4),
#  ('881110-1272', 'Torbjörn', 'Modig', '881110-1272', 'FMSF10', 4),
#  ('900227-2369', 'Märit', 'Aspegren', '900227-2369', 'FMSF15', 3),
#  ('951004-2346', 'Frida', 'Weidel', '951004-2346', 'FMSF15', 3),
#  ...]

# %% [markdown]
# m) Which students have taken 0 credits? [11] This problem
#    can be solved in several ways, first do it with an outer
#    join:

# %%
# %%sql

# %% [markdown]
# Now do the same thing using a subquery:

# %%
# %%sql

# %% [markdown]
# n) List the names and average grades of the 10 students with
#    the highest grade average?

# %%
# %%sql

# %% [markdown]
# o) List the social security number and total number of
#    credits for all students. Students with no credits should
#    be included in the listing, with 0 credits (not `NULL`).
#
#    If you do this with an outer join (and I recommend you
#    try it!) you might want to use the function
#    `coalesce(v1, v2, ...)`; it returns the first value which
#    is not `NULL`, so `coalesce(avg(grade), 0)` would give 0
#    if the were no grades (i.e., if `grade` were `NULL`), you
#    can also try the `ifnull` function.
#
#    (It may be a little bit tricky to get this query right,
#    if you're missing the students with 0 credits, don't
#    worry, your TA will help you get it right). [72]

# %%
# %%sql

# %% [markdown]
# p) Is there more than one student with the same name? If so,
#    who are these students and what are their social security
#    numbers? [7]
#
#    As usual there are several ways of solving this, try to
#    solve it using a `WITH`-statement where you create a
#    table with all duplicate names, and then use it in a
#    `JOIN`:

# %%
# %%sql

# %% [markdown]
# q) What 5 courses have the highest grade average?

# %%
# %%sql

# %% [markdown]
# r) (Not required) What are the 'best' initial letters of the
#    last names, i.e., if you take the average grades for each
#    first letter of the last name, which three initials have
#    the highest averages? That is, we want a table like (but
#    probably with other values):
#
# <center>
# <table rules="all">
#   <tr>
#    <th>initial</th>
#    <th>gpa</th>
#   </tr>
#   <tr>
#    <td>A</td>
#    <td>4.2</td>
#   </tr>
#   <tr>
#    <td>L</td>
#    <td>4.18</td>
#   </tr>
#   <tr>
#    <td>E</td>
#    <td>4.0</td>
#   </tr>
# </table>
# </center>

# %%
# %%sql
